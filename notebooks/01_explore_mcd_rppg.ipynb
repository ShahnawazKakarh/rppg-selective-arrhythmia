# %% [markdown]
# # MCD-rPPG exploration
#
# Inspect dataset structure, signal quality, biomarker coverage, and demographic distribution.

# %%
# TODO: load MCD-rPPG, plot sample pulse waveforms and ECG, summarize cohort.
